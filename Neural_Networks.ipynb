# %% [markdown]
# <a href="https://colab.research.google.com/github/Dima-salang/ai-ml-dl/blob/main/Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras

# %% [markdown]
# # Neural Networks
#
# Origins
# *   Algorithms that try to mimic the brain
# *   speech > images > NLP
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2023-11-04_002740381.png](data:image/png;base64,...)

# %% [markdown]
# Based on input data vector, these inputs can then be fed into the stacked neurons or hidden units in the neural network to make a prediction. Then, based on that prediction, we make another prediction which is the price.
#
# Neural networks derive economic value primarily from supervised learning, with applications ranging from online advertising to autonomous driving. Their adaptability is evident in tailored architectures like convolutional neural networks (CNNs) for images and recurrent neural networks (RNNs) for sequences. Despite long-standing technical foundations, the recent surge in neural network effectiveness is attributed to advancements in technology, enabling their transformative impact on interpreting both structured and unstructured data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In today's world scale drives artificial intelligence. We now have more computational power, algorithms, and more access to data due to digitalization.
